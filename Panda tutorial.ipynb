# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/home/kmandi/Downloads/transactions.csv")
# Out:
# /home/kmandi/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#         product_id   customer_id   store_id   promotion_id   month_of_year  \
# 0                1           157         24           1869              12
# 1                1           456         15              0               6
# 2                1           638         11              0               9
# 3                1           916          7              0               4
# 4                1           923         15              0               7
# ...            ...           ...        ...            ...             ...
# 173597        1559             0       8653              3               2
# 173598        1559             0       8659             13              12
# 173599        1559             0       9271             17               5
# 173600        1559             0       9318             16               9
# 173601        1559             0       9851              3               2
#
# ...

# %%
df.describe()
# Out:
#           product_id    customer_id       store_id   promotion_id  \
# count  173602.000000  173602.000000  173602.000000  173602.000000
# mean      785.700902    2702.927017    2575.507765     140.584653
# std       447.102348    3207.035413    3284.871923     384.341500
# min         1.000000       0.000000       2.000000       0.000000
# 25%       407.000000       0.000000      13.000000       0.000000
# 50%       790.000000    1168.000000      24.000000       7.000000
# 75%      1171.000000    5092.000000    5092.000000      17.000000
# max      1559.000000   10277.000000   10277.000000    1869.000000
#
#         month_of_year   the_year
# count   173602.000000   173602.0
# mean         6.638806     1997.0
# std          3.513033        0.0
# min          1.000000     1997.0
# 25%          4.000000     1997.0
# 50%          7.000000     1997.0
# 75%         10.000000     1997.0
# max         12.000000     1997.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173602 entries, 0 to 173601
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   product_id      173602 non-null  int64
#  1    customer_id    173602 non-null  int64
#  2    store_id       173602 non-null  int64
#  3    promotion_id   173602 non-null  int64
#  4    month_of_year  173602 non-null  int64
#  5    quarter        173602 non-null  object
#  6    the_year       173602 non-null  int64
#  7    store_sales    173602 non-null  object
#  8    store_cost     173602 non-null  object
#  9    unit_sales     173602 non-null  object
#  10   fact_count     173602 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 14.6+ MB

# %%
df.dtypes
# Out:
# product_id         int64
#  customer_id       int64
#  store_id          int64
#  promotion_id      int64
#  month_of_year     int64
#  quarter          object
#  the_year          int64
#  store_sales      object
#  store_cost       object
#  unit_sales       object
#  fact_count       object
# dtype: object

# %%
df.tail(30)
# Out:
#         product_id   customer_id   store_id   promotion_id   month_of_year  \
# 173572        1558             0       9554             13               3
# 173573        1558             0       9679              6               4
# 173574        1558           517      10209              7               8
# 173575        1559          1235        430             16              11
# 173576        1559           820        880             11               2
# 173577        1559             0       1173             13               7
# 173578        1559             0       1187             13              11
# 173579        1559             0       1533              3               1
# 173580        1559          1214       2224             16               2
# 173581        1559             0       3128              6              12
# 173582        1559           526       3164              7              12
# ...

# %%
st=pd.DataFrame({
"Name": ["Kartick Mandi","Yadul Hake","Pratap Das","Dipankar Sarkar","Rajesh Saha","Tuhina Mandal","Golam Kibria","Tulika Panjal","Mijan Hoshen","Chinmay Khan","Arnab BAnik","Motamil Anshari", "Najibule Islam","Shaddam Hosen","Monishita Ghose","Babu Pal","Ujjwal Mahato"],
"Dept":["CSE","TT","CSE","CSE","CSE","CSE","CSE","CSE","CSE","ME","CSE","CSE","TT","ME","CSE","EE","EE"],
"Age":[22, 20, 25, 23, 22, 21, 23, 22, 21, 23, 20, 22, 20, 24, 20, 23, 25],
"Sex":["Male","Male","Male","Male","Male","Female","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male"],
"Marke": [90, 89, 59, 64, 56, 40, 80, 70, 60, 98, 81, 66, 55, 41, 48, 54, 46]})

# %%
st
# Out:
#                Name Dept  Age     Sex  Marke
# 0     Kartick Mandi  CSE   22    Male     90
# 1        Yadul Hake   TT   20    Male     89
# 2        Pratap Das  CSE   25    Male     59
# 3   Dipankar Sarkar  CSE   23    Male     64
# 4       Rajesh Saha  CSE   22    Male     56
# 5     Tuhina Mandal  CSE   21  Female     40
# 6      Golam Kibria  CSE   23    Male     80
# 7     Tulika Panjal  CSE   22  Female     70
# 8      Mijan Hoshen  CSE   21    Male     60
# 9      Chinmay Khan   ME   23    Male     98
# 10      Arnab BAnik  CSE   20    Male     81
# 11  Motamil Anshari  CSE   22    Male     66
# 12   Najibule Islam   TT   20    Male     55
# 13    Shaddam Hosen   ME   24    Male     41
# 14  Monishita Ghose  CSE   20  Female     48
# 15         Babu Pal   EE   23    Male     54
# 16    Ujjwal Mahato   EE   25    Male     46

# %%
st[st["Age"]>24]
# Out:
#              Name Dept  Age   Sex  Marke
# 2      Pratap Das  CSE   25  Male     59
# 16  Ujjwal Mahato   EE   25  Male     46

# %%
age=pd.Series([22,23,24], name="Ages")

# %%
age
# Out:
# 0    22
# 1    23
# 2    24
# Name: Ages, dtype: int64

# %%
type(age)
# Out:
# pandas.core.series.Series

# %%
st.info
# Out:
# <bound method DataFrame.info of                Name Dept  Age     Sex  Marke
# 0     Kartick Mandi  CSE   22    Male     90
# 1        Yadul Hake   TT   20    Male     89
# 2        Pratap Das  CSE   25    Male     59
# 3   Dipankar Sarkar  CSE   23    Male     64
# 4       Rajesh Saha  CSE   22    Male     56
# 5     Tuhina Mandal  CSE   21  Female     40
# 6      Golam Kibria  CSE   23    Male     80
# 7     Tulika Panjal  CSE   22  Female     70
# 8      Mijan Hoshen  CSE   21    Male     60
# 9      Chinmay Khan   ME   23    Male     98
# 10      Arnab BAnik  CSE   20    Male     81
# 11  Motamil Anshari  CSE   22    Male     66
# 12   Najibule Islam   TT   20    Male     55
# 13    Shaddam Hosen   ME   24    Male     41
# 14  Monishita Ghose  CSE   20  Female     48
# 15         Babu Pal   EE   23    Male     54
# 16    Ujjwal Mahato   EE   25    Male     46>

# %%
st.describe()
# Out:
#              Age      Marke
# count  17.000000  17.000000
# mean   22.117647  64.529412
# std     1.653872  17.692222
# min    20.000000  40.000000
# 25%    21.000000  54.000000
# 50%    22.000000  60.000000
# 75%    23.000000  80.000000
# max    25.000000  98.000000

# %%
st.iloc[3:10, 2:3]
# Out:
#    Age
# 3   23
# 4   22
# 5   21
# 6   23
# 7   22
# 8   21
# 9   23

# %%
st.loc[(st["Age"] == 20) | (st["Age"] == 23), ["Name", "Dept"]]
# Out:
#                Name Dept
# 1        Yadul Hake   TT
# 3   Dipankar Sarkar  CSE
# 6      Golam Kibria  CSE
# 9      Chinmay Khan   ME
# 10      Arnab BAnik  CSE
# 12   Najibule Islam   TT
# 14  Monishita Ghose  CSE
# 15         Babu Pal   EE

# %%
st.iloc[3:10, 0:2]="Name"

# %%
st.plot()
# Out:
# <AxesSubplot:>

# %%
st["Marke"].plot()
# Out:
# <AxesSubplot:>

# %%
Financial_sample=pd.read_excel("/home/kmandi/Downloads/Financial Sample.xlsx")

# %%
Financial_sample
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
Financial_sample.plot(kind='box', subplots=True, layout=(4,3), sharex=False, sharey=False)
# Out:
# Units Sold                 AxesSubplot(0.125,0.71587;0.227941x0.16413)
# Manufacturing Price     AxesSubplot(0.398529,0.71587;0.227941x0.16413)
# Sale Price              AxesSubplot(0.672059,0.71587;0.227941x0.16413)
# Gross Sales               AxesSubplot(0.125,0.518913;0.227941x0.16413)
# Discounts              AxesSubplot(0.398529,0.518913;0.227941x0.16413)
#  Sales                 AxesSubplot(0.672059,0.518913;0.227941x0.16413)
# COGS                      AxesSubplot(0.125,0.321957;0.227941x0.16413)
# Profit                 AxesSubplot(0.398529,0.321957;0.227941x0.16413)
# Month Number           AxesSubplot(0.672059,0.321957;0.227941x0.16413)
# Year                         AxesSubplot(0.125,0.125;0.227941x0.16413)
# dtype: object

# %%
Financial_sample.plot.scatter(x="Units Sold", y="Sale Price", alpha=0.45)
# Out:
# <AxesSubplot:xlabel='Units Sold', ylabel='Sale Price'>

# %%
Financial_sample.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Units Sold'}>,
#         <AxesSubplot:title={'center':'Manufacturing Price'}>,
#         <AxesSubplot:title={'center':'Sale Price'}>],
#        [<AxesSubplot:title={'center':'Gross Sales'}>,
#         <AxesSubplot:title={'center':'Discounts'}>,
#         <AxesSubplot:title={'center':' Sales'}>],
#        [<AxesSubplot:title={'center':'COGS'}>,
#         <AxesSubplot:title={'center':'Profit'}>,
#         <AxesSubplot:title={'center':'Month Number'}>],
#        [<AxesSubplot:title={'center':'Year'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)
